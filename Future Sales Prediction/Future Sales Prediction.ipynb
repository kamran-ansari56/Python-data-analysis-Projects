# %%
# Importing the Libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Loading the data
data = pd.read_csv("Future Sales Prediction.csv")

# %%
# Analyse the Top 5 rows of the data
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# Now lets check if there are any null values in the data
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# Now let’s visualize the relationship between the amount spent on advertising on TV and units sold
import plotly.express as px
import plotly.graph_objects as go
figure = px.scatter(data_frame= data, x = "Sales", y= "TV", size = "TV", trendline= 'ols')
figure.show()
