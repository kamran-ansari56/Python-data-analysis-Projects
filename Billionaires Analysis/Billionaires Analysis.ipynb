# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loading the Dataset
data = pd.read_csv('Billionaire.csv')

# %%
# Analyse the Top 5 rows of the data
data.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
# Now let's check for more information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      2755 non-null   object
#  1   NetWorth  2755 non-null   object
#  2   Country   2755 non-null   object
#  3   Source    2755 non-null   object
#  4   Rank      2755 non-null   int64
#  5   Age       2676 non-null   float64
#  6   Industry  2755 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 150.8+ KB

# %%
# Now let's check for any null values in the data
data.isnull().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %%
# We have some null value in the data lets drop values before moving ahead
data.dropna(inplace= True)

# %%
# Now let's for any duplicated values in the data
data.duplicated().sum()
# Out:
# 0

# %%
# The NetWorth column in this dataset has a $ sign at the beginning of Billionaires’ Net worth and B at the end. So we need to remove these signs and convert the NetWorth column to float
data['NetWorth'] = data['NetWorth'].str.strip('$')
data['NetWorth'] = data['NetWorth'].str.strip('B')
data['NetWorth'] = data['NetWorth'].astype(float)

# %%
# Now let's have a look at the top 10 billionaires
df = data.sort_values(by = ['NetWorth'], ascending= False).head(10)
plt.figure(figsize = (20,10))
sns.histplot(x = 'Name', hue = 'NetWorth', data = df)
plt.show()

# %%
# Now let's have a look at the top 5 domains with the most number of billionaires
a = data['Source'].value_counts().head()
index = a.index
sources = a.values
custom_colors = ['skyblue', 'yellowgreen', 'tomato','blue','red']
plt.figure(figsize = (5,5))
plt.pie(sources, labels = index, colors = custom_colors)
central_circle = plt.Circle((0,0), 0.5, color = 'white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size = 12)
plt.title("Top 5 Domains to Become a Billionaire", fontsize = 20)
plt.show()

# %%
# Now let's have a look at the top 4 industries with the most number of billionaires
a = data['Industry'].value_counts().head()
index = a.index
industries = a.values
custom_colors = ["skyblue", "yellowgreen", 'tomato', "blue", "red"]
plt.figure(figsize=(5, 5))
plt.pie(industries, labels=index, colors=custom_colors)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Top 5 Industries with Most Number of Billionaires", fontsize=20)
plt.show()

# %%
# Now let’s have a look at the top 5 countries with the most number of billionaires
